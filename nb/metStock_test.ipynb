# %%
from api import metStockApi

# %%
metstock = metStockApi.MetStockApi()

# %%
df = metstock.get_chart_1m(code='000020', start='20220501', end='20220531')

# %%
df
# Out:
#                       open   high    low  close  volume
# date
# 2022-05-02 09:01:00  12450  12550  12450  12550    3049
# 2022-05-02 09:02:00  12500  12600  12500  12500     662
# 2022-05-02 09:03:00  12550  12600  12500  12600     392
# 2022-05-02 09:04:00  12600  12600  12550  12600    1092
# 2022-05-02 09:05:00  12600  12600  12600  12600     113
# ...                    ...    ...    ...    ...     ...
# 2022-05-31 15:17:00  11950  11950  11900  11900     263
# 2022-05-31 15:18:00  11950  11950  11900  11950     924
# 2022-05-31 15:19:00  11900  11950  11900  11900     380
# 2022-05-31 15:20:00  11900  11950  11900  11900    1969
# 2022-05-31 15:30:00  11900  11900  11900  11900  167393
#
# [5595 rows x 5 columns]

# %%
from reader import cybos_cli

# %%
cybos = cybos_cli.CybosDataReaderCli()

# %%
df_codes = cybos.sv_code_df()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [21], in <cell line: 1>()
# ----> 1 df_codes = cybos.sv_code_df()
#
# TypeError: 'DataFrame' object is not callable

# %%
df_codes
# Out:
# ('A000020',
#  'A000040',
#  'A000050',
#  'A000060',
#  'A000070',
#  'A000075',
#  'A000080',
#  'A000087',
#  'A000100',
#  'A000105',
#  'A000120',
#  'A000140',
#  'A000145',
#  'A000150',
#  'A000155',
#  'A000157',
#  'A000180',
#  'A000210',
#  'A000215',
#  'A000220',
#  'A000225',
#  'A000227',
#  'A000230',
#  'A000240',
#  'A000270',
#  'A000300',
#  'A000320',
#  'A000325',
#  'A000370',
#  'A000390',
#  'A000400',
#  'A000430',
#  'A000480',
#  'A000490',
#  'A000500',
#  'A000520',
#  'A000540',
#  'A000545',
#  'A000547',
#  'A000590',
#  'A000640',
#  'A000650',
#  'A000660',
#  'A000670',
#  'A000680',
#  'A000700',
#  'A000720',
#  'A000725',
#  'A000760',
#  'A000810',
#  'A000815',
#  'A000850',
#  'A000860',
#  'A000880',
#  'A000885',
#  'A00088K',
#  'A000890',
#  'A000910',
#  'A000950',
#  'A000970',
#  'A000990',
#  'A000995',
#  'A001020',
#  'A001040',
#  'A001045',
#  'A00104K',
#  'A001060',
#  'A001065',
#  'A001067',
#  'A001070',
#  'A001080',
# ...
