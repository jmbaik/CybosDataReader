# %%
from pykrx import stock
import pandas as pd

# %%
df = stock.get_market_fundamental('20220819')

# %%
df
# Out:
#           BPS    PER   PBR   EPS   DIV   DPS
# 티커
# 095570   8075   4.92  1.04  1707  3.22   270
# 006840  45961   0.00  0.36     0  1.22   200
# 027410  16393   6.21  0.26   684  2.59   110
# 282330  46849  20.07  3.66  8547  1.75  3000
# 138930  28745   2.93  0.24  2341  8.18   560
# ...       ...    ...   ...   ...   ...   ...
# 005010  15984   6.59  0.41   987  2.46   160
# 000540  10599   4.03  0.33   873  0.00     0
# 000547      0   0.00  0.00     0  0.00     0
# 000545      0   0.00  0.00     0  0.00     0
# 003280    428  15.42  4.25   118  0.00     0
#
# [910 rows x 6 columns]

# %%
tickers = stock.get_market_ticker_list('20220819', market='KOSPI')

# %%
code_names = []
for _tick in tickers:
    _name = stock.get_market_ticker_name(_tick)
    dic_code = { 'code': _tick, 'name' : _name, 'market': 'KOSPI' }
    code_names.append(dic_code)

# %%
code_names
# Out:
# [{'code': '095570', 'name': 'AJ네트웍스', 'market': 'KOSPI'},
#  {'code': '006840', 'name': 'AK홀딩스', 'market': 'KOSPI'},
#  {'code': '027410', 'name': 'BGF', 'market': 'KOSPI'},
#  {'code': '282330', 'name': 'BGF리테일', 'market': 'KOSPI'},
#  {'code': '138930', 'name': 'BNK금융지주', 'market': 'KOSPI'},
#  {'code': '001460', 'name': 'BYC', 'market': 'KOSPI'},
#  {'code': '001465', 'name': 'BYC우', 'market': 'KOSPI'},
#  {'code': '001040', 'name': 'CJ', 'market': 'KOSPI'},
#  {'code': '079160', 'name': 'CJ CGV', 'market': 'KOSPI'},
#  {'code': '00104K', 'name': 'CJ4우(전환)', 'market': 'KOSPI'},
#  {'code': '000120', 'name': 'CJ대한통운', 'market': 'KOSPI'},
#  {'code': '011150', 'name': 'CJ씨푸드', 'market': 'KOSPI'},
#  {'code': '011155', 'name': 'CJ씨푸드1우', 'market': 'KOSPI'},
#  {'code': '001045', 'name': 'CJ우', 'market': 'KOSPI'},
#  {'code': '097950', 'name': 'CJ제일제당', 'market': 'KOSPI'},
#  {'code': '097955', 'name': 'CJ제일제당 우', 'market': 'KOSPI'},
# ...

# %%
df = stock.get_market_fundamental('20190104', '20220819', '005930')

# %%
df
# Out:
#               BPS    PER   PBR   EPS   DIV   DPS
# 날짜
# 2019-01-04  28126   6.24  1.33  5997  2.27   850
# 2019-01-07  28126   6.46  1.38  5997  2.19   850
# 2019-01-08  28126   6.35  1.35  5997  2.23   850
# 2019-01-09  28126   6.60  1.41  5997  2.15   850
# 2019-01-10  28126   6.64  1.42  5997  2.14   850
# ...           ...    ...   ...   ...   ...   ...
# 2022-08-12  43611  10.42  1.38  5777  2.40  1444
# 2022-08-16  43611  10.56  1.40  5777  2.37  1444
# 2022-08-17  43611  10.46  1.38  5777  2.39  1444
# 2022-08-18  43611  10.65  1.41  5777  2.35  1444
# 2022-08-19  43611  10.54  1.40  5777  2.37  1444
#
# [896 rows x 6 columns]
